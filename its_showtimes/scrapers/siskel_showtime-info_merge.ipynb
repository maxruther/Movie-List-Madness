# %%
import pandas as pd
import os

from utils import load_latest_data

# %%
os.getcwd()
# Out:
# 'c:\\Users\\maxru\\eclipse-workspace\\movie_list_dvlp\\movie_list_parsing\\its_showtimes\\scrapers'

# %%
s_times = pd.read_pickle('..\\..\\data\\pkl\\siskel\\single_scrapes\\siskel_showtimes_2025-06-25.pkl')
s_times.head()
# Out:
#                    Title  Year               Director  \
# 0           MATERIALISTS  2025            Celine Song
# 1                 IMAGES  1972          Robert Altman
# 2           MATERIALISTS  2025            Celine Song
# 3  A PHOTOGRAPHIC MEMORY  2024  Rachel Elizabeth Seed
# 4           MATERIALISTS  2025            Celine Song
#
#                     Showtime Theater                   Scrape_Datetime
# 0  2025-06-25T22:45:00+00:00  Siskel  2025-06-25T21:23:19.857608+00:00
# 1  2025-06-25T23:00:00+00:00  Siskel  2025-06-25T21:23:19.857608+00:00
# 2  2025-06-26T01:15:00+00:00  Siskel  2025-06-25T21:23:19.857608+00:00
# 3  2025-06-26T01:30:00+00:00  Siskel  2025-06-25T21:23:19.857608+00:00
# 4  2025-06-26T22:45:00+00:00  Siskel  2025-06-25T21:23:19.857608+00:00

# %%
s_info = pd.read_pickle('..\\..\\data\\pkl\\siskel\\single_scrapes\\siskel_show_info_2025-06-25.pkl')
s_info.head()
# Out:
#                    Title  Year               Director Runtime  \
# 0           MATERIALISTS  2025            Celine Song     113
# 1                 IMAGES  1972          Robert Altman     104
# 2  A PHOTOGRAPHIC MEMORY  2024  Rachel Elizabeth Seed      87
# 3              LIGHTNING  1952           Mikio Naruse      87
# 4         FEMALE TROUBLE  1974            John Waters      89
#
#                         Series                                 Tags Country  \
# 0  New Releases & Restorations                          Now Playing     USA
# 1     Robert Altman Centennial                                           UK
# 2  New Releases & Restorations  Now Playing, Director In Attendance     USA
# 3                                                              35mm   Japan
# 4                  Summer Camp                                 35mm     USA
#
#                                                 Meta  \
# 0                       In English | Format: Digital
# ...
