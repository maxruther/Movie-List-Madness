# %% [markdown]
# # Never mind - unnecessary
# ### Instead, merge this data within MySQL db, with a view

# %%
import pandas as pd

# %%
sisk_df = pd.read_pickle('..\..\data\pkl\musicbox\single_scrapes\mc_scrape\musicbox_show_info_2025-07-16_mc_searchresults.pkl')
sisk_df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\maxru\AppData\Local\Temp\ipykernel_22892\1512982550.py:1: SyntaxWarning: invalid escape sequence '\.'
#   sisk_df = pd.read_pickle('..\..\data\pkl\musicbox\single_scrapes\mc_scrape\musicbox_show_info_2025-07-16_mc_searchresults.pkl')
#                               Title Searched  \
# 0                       IN THE MOOD FOR LOVE
# 1                            KILL THE JOCKEY
# 2                           CASTRATION MOVIE
# 3                           CASTRATION MOVIE
# 4                           CASTRATION MOVIE
# 5                           CASTRATION MOVIE
# 6                           CASTRATION MOVIE
# 7                           CASTRATION MOVIE
# 8  STACEY AND MICHAEL'S SHOWCASE OF SHORTS X
# 9                    MY BEST FRIENDS WEDDING
#
#                                       Title Result  Titles Fuzzy Sim  \
# 0                             In the Mood for Love              1.00
# 1                                  Kill the Jockey              1.00
# 2                            MoviePass, MovieCrash              0.43
# 3                      The Super Mario Bros. Movie              0.51
# 4             Nirvanna the Band the Show the Movie              0.42
# 5                    Cheech and Chong's Last Movie              0.49
# 6  The Day the Earth Blew Up: A Looney Tunes Movie              0.38
# 7                                              NaN               NaN
# 8                                              NaN               NaN
# 9                         My Best Friend's Wedding              0.98
#
#    Titles Cosine Sim Year Searched Year Result   Director Searched  \
# 0              1.000          2001        2001        Wong Kar Wai
# 1              1.000          2024        2025         Luis Ortega
# 2              0.000          2024        2024        Louise Weard
# 3              0.316          2024        2023        Louise Weard
# 4              0.196          2024        2025        Louise Weard
# 5              0.316          2024        2025        Louise Weard
# 6              0.213          2024        2025        Louise Weard
# 7                NaN          2024         NaN        Louise Weard
# 8                NaN          2025         NaN                None
# 9              0.750          1997        1997  Ron BassP.J. Hogan
#
#                                      Director Result  Directors Fuzzy Sim  \
# 0                                       Kar-Wai Wong                 0.50
# 1                                        Luis Ortega                 1.00
# 2                                  Muta'Ali Muhammad                 0.34
# 3  Aaron Horvath, Michael Jelenic, Pierre Leduc, ...                 0.20
# 4                                       Matt Johnson                 0.17
# 5                                   David L. Bushell                 0.29
# 6                                   Peter Browngardt                 0.43
# 7                                                NaN                  NaN
# 8                                                NaN                  NaN
# 9                                         P.J. Hogan                 0.71
#
#    Directors Cosine Sim                                               Link
# 0                 1.000                       /movie/in-the-mood-for-love/
# 1                 1.000                            /movie/kill-the-jockey/
# 2                 0.000                       /movie/moviepass-moviecrash/
# 3                 0.000                 /movie/the-super-mario-bros-movie/
# 4                 0.000       /movie/nirvanna-the-band-the-show-the-movie/
# 5                 0.000               /movie/cheech-and-chongs-last-movie/
# 6                 0.000  /movie/the-day-the-earth-blew-up-a-looney-tune...
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                 0.577                    /movie/my-best-friends-wedding/

# %%
sisk_df['Year Result'] = pd.to_numeric(sisk_df['Year Result'], errors='coerce').astype("Int32")

# %%
sisk_df.head(10)
sisk_df.head(10)['Year Result']
# Out:
# 0    2001
# 1    2025
# 2    2024
# 3    2023
# 4    2025
# 5    2025
# 6    2025
# 7    <NA>
# 8    <NA>
# 9    1997
# Name: Year Result, dtype: Int32

# %%
sisk_df['Year Result'] = sisk_df['Year Result'].where(sisk_df['Year Result'].notna(), pd.NA)
sisk_df['Year Result'].astype('Int32')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\integer.py:53, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      52 try:
# ---> 53     return values.astype(dtype, casting="safe", copy=copy)
#      54 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int32') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 sisk_df['Year Result'] = sisk_df['Year Result'].where(sisk_df['Year Result'].notna(), pd.NA)
# ----> 2 sisk_df['Year Result'].astype('Int32')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:80, in _astype_nansafe(arr, dtype, copy, skipna)
#      78 # dispatch on extension dtype if needed
#      79 if isinstance(dtype, ExtensionDtype):
# ---> 80     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      82 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      83     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py:152, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     150 @classmethod
#     151 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 152     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     153     return cls(values, mask)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\numeric.py:272, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     270 dtype_cls = cls._dtype_cls
#     271 default_dtype = dtype_cls._default_np_dtype
# --> 272 values, mask, _, _ = _coerce_to_data_and_mask(
#     273     value, dtype, copy, dtype_cls, default_dtype
#     274 )
#     275 return values, mask
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\numeric.py:229, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls, default_dtype)
#     227     values = values.astype(dtype, copy=copy)
#     228 else:
# --> 229     values = dtype_cls._safe_cast(values, dtype, copy=False)
#     231 return values, mask, dtype, inferred_type
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\integer.py:59, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      56 if (casted == values).all():
#      57     return casted
# ---> 59 raise TypeError(
#      60     f"cannot safely cast non-equivalent {values.dtype} to {np.dtype(dtype)}"
#      61 ) from err
#
# TypeError: cannot safely cast non-equivalent object to int32

# %%
sisk_df['Year Result'] = sisk_df[pd.to_numeric(sisk_df['Year Result'], errors='coerce').isna()][['Year Result']]
# Out:
#    Year Result
# 7          NaN
# 8          NaN
# 11         NaN
# 15         NaN
# 16         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 26         NaN
# 28         NaN
# 31         NaN
# 33         NaN
# 34         NaN
# 38         NaN
# 48         NaN
# 57         NaN
# 61         NaN
# 63         NaN
# 66         NaN
# 70         NaN
# 71         NaN

# %%
sisk_df['Year Result'].astype('Int32')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\integer.py:53, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      52 try:
# ---> 53     return values.astype(dtype, casting="safe", copy=copy)
#      54 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int32') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sisk_df['Year Result'].astype('Int32')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\dtypes\astype.py:80, in _astype_nansafe(arr, dtype, copy, skipna)
#      78 # dispatch on extension dtype if needed
#      79 if isinstance(dtype, ExtensionDtype):
# ---> 80     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      82 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      83     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py:152, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     150 @classmethod
#     151 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 152     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     153     return cls(values, mask)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\numeric.py:272, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     270 dtype_cls = cls._dtype_cls
#     271 default_dtype = dtype_cls._default_np_dtype
# --> 272 values, mask, _, _ = _coerce_to_data_and_mask(
#     273     value, dtype, copy, dtype_cls, default_dtype
#     274 )
#     275 return values, mask
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\numeric.py:229, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls, default_dtype)
#     227     values = values.astype(dtype, copy=copy)
#     228 else:
# --> 229     values = dtype_cls._safe_cast(values, dtype, copy=False)
#     231 return values, mask, dtype, inferred_type
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\integer.py:59, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      56 if (casted == values).all():
#      57     return casted
# ---> 59 raise TypeError(
#      60     f"cannot safely cast non-equivalent {values.dtype} to {np.dtype(dtype)}"
#      61 ) from err
#
# TypeError: cannot safely cast non-equivalent object to int32

# %%
sisk_df = pd.read_pickle('..\..\data\pkl\siskel\single_scrapes\siskel_show_info_2025-06-25.pkl')
sisk_df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\maxru\AppData\Local\Temp\ipykernel_30864\2314321803.py:1: SyntaxWarning: invalid escape sequence '\.'
#   sisk_df = pd.read_pickle('..\..\data\pkl\siskel\single_scrapes\siskel_show_info_2025-06-25.pkl')
#                    Title  Year               Director Runtime  \
# 0           MATERIALISTS  2025            Celine Song     113
# 1                 IMAGES  1972          Robert Altman     104
# 2  A PHOTOGRAPHIC MEMORY  2024  Rachel Elizabeth Seed      87
# 3              LIGHTNING  1952           Mikio Naruse      87
# 4         FEMALE TROUBLE  1974            John Waters      89
#
#                         Series                                 Tags Country  \
# 0  New Releases & Restorations                          Now Playing     USA
# 1     Robert Altman Centennial                                           UK
# 2  New Releases & Restorations  Now Playing, Director In Attendance     USA
# 3                                                              35mm   Japan
# 4                  Summer Camp                                 35mm     USA
#
#                                                 Meta  \
# 0                       In English | Format: Digital
# 1  In English and French with English subtitles |...
# 2                       In English | Format: Digital
# 3  In Japanese with English subtitles | Format: I...
# 4                          In English | Format: 35mm
#
#                                                 Link  \
# 0     https://www.siskelfilmcenter.org//materialists
# 1           https://www.siskelfilmcenter.org//images
# 2  https://www.siskelfilmcenter.org//photographic...
# 3        https://www.siskelfilmcenter.org//lightning
# 4   https://www.siskelfilmcenter.org//female-trouble
#
#                                        Show  \
# 0                              MATERIALISTS
# 1                                    IMAGES
# 2                     A PHOTOGRAPHIC MEMORY
# 3  Chicago Film Society Presents: LIGHTNING
# 4                            FEMALE TROUBLE
#
#                                          Description Theater  \
# 0  Following her Academy Award nominated, critica...  Siskel
# 1  In Altman’s psychological thriller, the mental...  Siskel
# 2  Rachel Elizabeth Seed was only 18 months old w...  Siskel
# 3  You've never met a more cheerful urban ambassa...  Siskel
# 4  This series would be incomplete without a film...  Siskel
#
#                     Scrape_Datetime
# 0  2025-06-25T21:23:19.857608+00:00
# 1  2025-06-25T21:23:19.857608+00:00
# 2  2025-06-25T21:23:19.857608+00:00
# 3  2025-06-25T21:23:19.857608+00:00
# 4  2025-06-25T21:23:19.857608+00:00

# %%
mb_df = pd.read_pickle('..\..\data\pkl\musicbox\single_scrapes\musicbox_show_info_2025-06-25.pkl')
mb_df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\maxru\AppData\Local\Temp\ipykernel_30864\661555547.py:1: SyntaxWarning: invalid escape sequence '\.'
#   mb_df = pd.read_pickle('..\..\data\pkl\musicbox\single_scrapes\musicbox_show_info_2025-06-25.pkl')
#                      Title  Year  Runtime Format          Director  \
# 0                PAVEMENTS  2025      128    DCP   Alex Ross Perry
# 1    THE PHOENICIAN SCHEME  2025      101    DCP      Wes Anderson
# 2              EVIL PUDDLE  2025       90    DCP  Charles Roxburgh
# 3               GOING DOWN  1983       96    DCP      Haydn Keenan
# 4  WET HOT AMERICAN SUMMER  2001       97    NaN        David Wain
#
#                                              Writer  \
# 0                                   Alex Ross Perry
# 1                       Wes Anderson, Roman Coppola
# 2                                       Matt Farley
# 3  Melissa Woods, Julie Barry, Moira MacLaine-Cross
# 4                                 Michael Showalter
#
#                                                 Cast  \
# 0        Joe Keery, Jason Schwartzman, Tim Heidecker
# 1    Benicio del Toro, Mia Threapleton, Michael Cera
# 2                                        Matt Farley
# 3              Tracy Mann, Vera Plevnik, Julie Barry
# 4  Janeane Garofalo, David Hyde Pierce, Michael S...
#
#                                          Description  \
# 0  PAVEMENTS is a movie about Pavement the band—a...
# 1  The story of a family and a family business. B...
# 2  When evil, deadly water starts pooling around ...
# 3  Middle-class Karli (Tracy Mann, Hard Knocks), ...
# 4  Set on the last day of camp, in the hot summer...
#
#                                                 Link    Theater  \
# 0  https://musicboxtheatre.com/films-and-events/p...  Music Box
# 1  https://musicboxtheatre.com/films-and-events/t...  Music Box
# 2  https://musicboxtheatre.com/films-and-events/e...  Music Box
# 3  https://musicboxtheatre.com/films-and-events/g...  Music Box
# 4  https://musicboxtheatre.com/films-and-events/w...  Music Box
#
#                     Scrape_Datetime
# 0  2025-06-25T21:23:52.470408+00:00
# 1  2025-06-25T21:23:52.470408+00:00
# 2  2025-06-25T21:23:52.470408+00:00
# 3  2025-06-25T21:23:52.470408+00:00
# 4  2025-06-25T21:23:52.470408+00:00

# %%
[x for x in sisk_df.columns if x not in mb_df.columns]
# Out:
# ['Series', 'Tags', 'Country', 'Meta', 'Show']

# %%
[x for x in mb_df.columns if x not in sisk_df.columns]
# Out:
# ['Format', 'Writer', 'Cast']

# %%
[x for x in mb_df.columns if x in sisk_df.columns]
# Out:
# ['Title',
#  'Year',
#  'Runtime',
#  'Director',
#  'Description',
#  'Link',
#  'Theater',
#  'Scrape_Datetime']

# %%
merged_df = pd.concat([sisk_df, mb_df])
# merged_df = merged_df.sort_values(by=['Showtime', 'Theater']).reset_index(drop=True)
merged_df
# Out:
#                                           Title  Year               Director  \
# 0                                  MATERIALISTS  2025            Celine Song
# 1                                        IMAGES  1972          Robert Altman
# 2                         A PHOTOGRAPHIC MEMORY  2024  Rachel Elizabeth Seed
# 3                                     LIGHTNING  1952           Mikio Naruse
# 4                                FEMALE TROUBLE  1974            John Waters
# ..                                          ...   ...                    ...
# 66                                        JUICE  1984  Arthur J. Bressan Jr.
# 67                  FABULOUS FLEISCHER CARTOONS  None          Max Fleischer
# 68  A NIGHTMARE ON ELM STREET 3: DREAM WARRIORS  1987          Chuck Russell
# 69                           25 CATS FROM QATAR  2025              Mye Hoang
# 70                                      JUMANJI  1995           Joe Johnston
#
#    Runtime                       Series                                 Tags  \
# 0      113  New Releases & Restorations                          Now Playing
# 1      104     Robert Altman Centennial
# 2       87  New Releases & Restorations  Now Playing, Director In Attendance
# 3       87                                                              35mm
# 4       89                  Summer Camp                                 35mm
# ..     ...                          ...                                  ...
# 66      72                          NaN                                  NaN
# 67      80                          NaN                                  NaN
# 68      96                          NaN                                  NaN
# 69      95                          NaN                                  NaN
# 70     104                          NaN                                  NaN
#
#    Country                                               Meta  \
# 0      USA                       In English | Format: Digital
# 1       UK  In English and French with English subtitles |...
# 2      USA                       In English | Format: Digital
# 3    Japan  In Japanese with English subtitles | Format: I...
# 4      USA                          In English | Format: 35mm
# ..     ...                                                ...
# 66     NaN                                                NaN
# 67     NaN                                                NaN
# 68     NaN                                                NaN
# 69     NaN                                                NaN
# 70     NaN                                                NaN
#
#                                                  Link  \
# 0      https://www.siskelfilmcenter.org//materialists
# 1            https://www.siskelfilmcenter.org//images
# 2   https://www.siskelfilmcenter.org//photographic...
# 3         https://www.siskelfilmcenter.org//lightning
# 4    https://www.siskelfilmcenter.org//female-trouble
# ..                                                ...
# 66  https://musicboxtheatre.com/films-and-events/j...
# 67  https://musicboxtheatre.com/films-and-events/f...
# 68  https://musicboxtheatre.com/films-and-events/a...
# 69  https://musicboxtheatre.com/films-and-events/2...
# 70  https://musicboxtheatre.com/films-and-events/j...
#
#                                         Show  \
# 0                               MATERIALISTS
# 1                                     IMAGES
# 2                      A PHOTOGRAPHIC MEMORY
# 3   Chicago Film Society Presents: LIGHTNING
# 4                             FEMALE TROUBLE
# ..                                       ...
# 66                                       NaN
# 67                                       NaN
# 68                                       NaN
# 69                                       NaN
# 70                                       NaN
#
#                                           Description    Theater  \
# 0   Following her Academy Award nominated, critica...     Siskel
# 1   In Altman’s psychological thriller, the mental...     Siskel
# 2   Rachel Elizabeth Seed was only 18 months old w...     Siskel
# 3   You've never met a more cheerful urban ambassa...     Siskel
# 4   This series would be incomplete without a film...     Siskel
# ..                                                ...        ...
# 66  Jim Bennett (Michael Christopher) is a photogr...  Music Box
# 67  Max Fleischer is one of the most renown pionee...  Music Box
# 68  During a hallucinatory incident, young Kristen...  Music Box
# 69  Qatar is one of the world’s wealthiest nations...  Music Box
# 70  Robin Williams, Kirsten Dunst and Bonnie Hunt ...  Music Box
#
#                      Scrape_Datetime Format  \
# 0   2025-06-25T21:23:19.857608+00:00    NaN
# 1   2025-06-25T21:23:19.857608+00:00    NaN
# 2   2025-06-25T21:23:19.857608+00:00    NaN
# 3   2025-06-25T21:23:19.857608+00:00    NaN
# 4   2025-06-25T21:23:19.857608+00:00    NaN
# ..                               ...    ...
# 66  2025-06-25T21:23:52.470408+00:00    DCP
# 67  2025-06-25T21:23:52.470408+00:00    DCP
# 68  2025-06-25T21:23:52.470408+00:00   35mm
# 69  2025-06-25T21:23:52.470408+00:00    DCP
# 70  2025-06-25T21:23:52.470408+00:00    NaN
#
#                                          Writer  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 66                        Arthur J. Bressan Jr.
# 67                                          NaN
# 68     Wes Craven, Bruce Wagner, Frank Darabont
# 69                                          NaN
# 70  Jonathan Hensleigh, Greg Taylor, Jim Strain
#
#                                                  Cast
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 66     Michael Christopher, Butch La Cross, Eric Ryan
# 67                                                NaN
# 68   Heather Langenkamp, Robert Englund, Craig Wasson
# 69                                                NaN
# 70  Robin Williams, Bonnie Hunt, David Alan Grier,...
#
# [111 rows x 16 columns]

# %%
merged_df['Showtime'] = pd.to_datetime(merged_df['Showtime'], utc=True, errors='raise')
print(merged_df.dtypes)
merged_df.head()
# Out:
# Title                    object
# Year                     object
# Director                 object
# Showtime    datetime64[ns, UTC]
# Theater                  object
# dtype: object
#                          Title  Year                 Director  \
# 0    DAVID LYNCH: THE ART LIFE  2016  Jon Nguyen, Rick Barnes
# 1  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 2             SUNSET BOULEVARD  1950             Billy Wilder
# 3        SECRET MALL APARTMENT  2024           Jeremy Workman
# 4             MULHOLLAND DRIVE  2001              David Lynch
#
#                    Showtime    Theater
# 0 2025-04-18 18:00:00+00:00  Music Box
# 1 2025-04-18 19:00:00+00:00  Music Box
# 2 2025-04-18 20:00:00+00:00  Music Box
# 3 2025-04-18 21:15:00+00:00  Music Box
# 4 2025-04-18 22:45:00+00:00  Music Box
