# %%
import pandas as pd

# %%
sisk_df = pd.read_pickle('..\..\data\pkl\siskel\siskel_showtimes.pkl')
sisk_df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\maxru\AppData\Local\Temp\ipykernel_28260\3171686001.py:1: SyntaxWarning: invalid escape sequence '\.'
#   sisk_df = pd.read_pickle('..\..\data\pkl\siskel\siskel_showtimes.pkl')
#              Title  Year         Director                   Showtime
# 0       GRAND TOUR  2024     Miguel Gomes  2025-04-18T22:45:00+00:00
# 1  KILLER OF SHEEP  1978  Charles Burnett  2025-04-18T23:00:00+00:00
# 2     A FIDAI FILM  2024   Kamal Aljafari  2025-04-19T01:00:00+00:00
# 3  KILLER OF SHEEP  1978  Charles Burnett  2025-04-19T01:30:00+00:00
# 4  KILLER OF SHEEP  1978  Charles Burnett  2025-04-19T17:30:00+00:00

# %%
mb_df = pd.read_pickle('..\..\data\pkl\musicbox\musicbox_showtimes.pkl')
mb_df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\maxru\AppData\Local\Temp\ipykernel_28260\540407013.py:1: SyntaxWarning: invalid escape sequence '\.'
#   mb_df = pd.read_pickle('..\..\data\pkl\musicbox\musicbox_showtimes.pkl')
#                          Title  Year                 Director  \
# 0    DAVID LYNCH: THE ART LIFE  2016  Jon Nguyen, Rick Barnes
# 1  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 2  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 3             SUNSET BOULEVARD  1950             Billy Wilder
# 4        SECRET MALL APARTMENT  2024           Jeremy Workman
#
#                     Showtime
# 0  2025-04-18T18:00:00+00:00
# 1  2025-04-18T19:00:00+00:00
# 2  2025-04-18T23:45:00+00:00
# 3  2025-04-18T20:00:00+00:00
# 4  2025-04-18T21:15:00+00:00

# %%
sisk_df['Theater'] = 'Siskel'
sisk_df.head()
# Out:
#              Title  Year         Director                   Showtime Theater
# 0       GRAND TOUR  2024     Miguel Gomes  2025-04-18T22:45:00+00:00  Siskel
# 1  KILLER OF SHEEP  1978  Charles Burnett  2025-04-18T23:00:00+00:00  Siskel
# 2     A FIDAI FILM  2024   Kamal Aljafari  2025-04-19T01:00:00+00:00  Siskel
# 3  KILLER OF SHEEP  1978  Charles Burnett  2025-04-19T01:30:00+00:00  Siskel
# 4  KILLER OF SHEEP  1978  Charles Burnett  2025-04-19T17:30:00+00:00  Siskel

# %%
mb_df['Theater'] = 'Music Box'
mb_df.head()
# Out:
#                          Title  Year                 Director  \
# 0    DAVID LYNCH: THE ART LIFE  2016  Jon Nguyen, Rick Barnes
# 1  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 2  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 3             SUNSET BOULEVARD  1950             Billy Wilder
# 4        SECRET MALL APARTMENT  2024           Jeremy Workman
#
#                     Showtime    Theater
# 0  2025-04-18T18:00:00+00:00  Music Box
# 1  2025-04-18T19:00:00+00:00  Music Box
# 2  2025-04-18T23:45:00+00:00  Music Box
# 3  2025-04-18T20:00:00+00:00  Music Box
# 4  2025-04-18T21:15:00+00:00  Music Box

# %%
merged_df = pd.concat([sisk_df, mb_df])
merged_df = merged_df.sort_values(by=['Showtime', 'Theater']).reset_index(drop=True)
merged_df
# Out:
#                                  Title  Year  \
# 0            DAVID LYNCH: THE ART LIFE  2016
# 1          THE BALLAD OF WALLIS ISLAND  2025
# 2                     SUNSET BOULEVARD  1950
# 3                SECRET MALL APARTMENT  2024
# 4                     MULHOLLAND DRIVE  2001
# ..                                 ...   ...
# 489              THE FRENCH CONNECTION  1971
# 490                          KING KONG  1933
# 491           A STREETCAR NAMED DESIRE  2025
# 492  FILMS FOR ONE TO EIGHT PROJECTORS  2008
# 493                        42ND STREET  1933
#
#                                    Director                   Showtime  \
# 0                   Jon Nguyen, Rick Barnes  2025-04-18T18:00:00+00:00
# 1                           James Griffiths  2025-04-18T19:00:00+00:00
# 2                              Billy Wilder  2025-04-18T20:00:00+00:00
# 3                            Jeremy Workman  2025-04-18T21:15:00+00:00
# 4                               David Lynch  2025-04-18T22:45:00+00:00
# ..                                      ...                        ...
# 489                        William Friedkin  2025-06-29T16:30:00+00:00
# 490  Merian C. Cooper, Ernest B. Schoedsack  2025-06-29T17:00:00+00:00
# 491                        Benedict Andrews  2025-06-29T19:15:00+00:00
# 492                             Roger Beebe  2025-06-30T23:00:00+00:00
# 493                             Lloyd Bacom  2025-07-01T01:30:00+00:00
#
#        Theater
# 0    Music Box
# 1    Music Box
# 2    Music Box
# 3    Music Box
# 4    Music Box
# ..         ...
# 489  Music Box
# 490     Siskel
# 491     Siskel
# 492     Siskel
# 493     Siskel
#
# [494 rows x 5 columns]

# %%
merged_df['Showtime'] = pd.to_datetime(merged_df['Showtime'], utc=True, errors='raise')
print(merged_df.dtypes)
merged_df.head()
# Out:
# Title                    object
# Year                     object
# Director                 object
# Showtime    datetime64[ns, UTC]
# Theater                  object
# dtype: object
#                          Title  Year                 Director  \
# 0    DAVID LYNCH: THE ART LIFE  2016  Jon Nguyen, Rick Barnes
# 1  THE BALLAD OF WALLIS ISLAND  2025          James Griffiths
# 2             SUNSET BOULEVARD  1950             Billy Wilder
# 3        SECRET MALL APARTMENT  2024           Jeremy Workman
# 4             MULHOLLAND DRIVE  2001              David Lynch
#
#                    Showtime    Theater
# 0 2025-04-18 18:00:00+00:00  Music Box
# 1 2025-04-18 19:00:00+00:00  Music Box
# 2 2025-04-18 20:00:00+00:00  Music Box
# 3 2025-04-18 21:15:00+00:00  Music Box
# 4 2025-04-18 22:45:00+00:00  Music Box
