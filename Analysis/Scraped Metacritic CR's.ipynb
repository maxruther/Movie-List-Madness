# %% [markdown]
# # Digging Deeper into Reviews
# ## Scraping Metacritic's individual critic reviews
# ### Movie List Project - Notebook #4
# ### Max Ruther

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

import os

from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %%
rand_st = 44

# %%
engine = create_engine('mysql://root:yos@localhost/moviedb')
conn = engine.connect()

# %% [markdown]
# ## Import data from a preceding analysis

# %%
curr_dir = os.getcwd()
data_filename = 'mList_df_all.csv'
data_filepath = os.path.join(curr_dir, '..', 'data', data_filename)
data_filepath
# Out:
# 'C:\\Users\\maxru\\eclipse-workspace\\movie_list_dvlp\\movie_list_parsing\\Analysis (Jupyter NBs)\\..\\data\\mList_df_all.csv'

# %%
watch_df = pd.read_csv(data_filepath, index_col='Movie_ID')
print(watch_df.shape)
watch_df.head()
# Out:
# (162, 7)
#                             Title  Year  IMDB_Score  RT_Score  MetaC_Score  \
# Movie_ID
# 9                       Sing Sing  2023        0.82      0.98         0.84
# 10             The Nature of Love  2023        0.70      0.92         0.80
# 11                         Oddity  2024        0.68      0.96         0.78
# 12                    Challengers  2024        0.72      0.88         0.82
# 13        Furiosa: A Mad Max Saga  2024        0.75      0.90         0.79
#
#           Ebert_Score  anyAwesome
# Movie_ID
# 9                 4.0           0
# 10                4.0           0
# 11                3.5           0
# 12                3.5           0
# 13                4.0           1

# %% [markdown]
# ## Import all individual critic ratings from Metacritic

# %%
mcr_df = pd.read_csv('../metacritic_cr_masterlist.csv', index_col=0)
mcr_df.head()
# Out:
#             Film      Publication  Score          Critic  \
# 0  Thelma (2024)     Boston Globe    100  Odie Henderson
# 1  Thelma (2024)     Original-Cin    100       Liz Braun
# 2  Thelma (2024)    The A.V. Club    100     Cindy White
# 3  Thelma (2024)  Washington Post    100         Ty Burr
# 4  Thelma (2024)          TheWrap     90   Kristen Lopez
#
#                                              Snippet  Date Written
# 0  This is one of the year’s best films, and the ...  Jun 18, 2024
# 1  Thelma is really entertaining. The cast (which...  Jun 18, 2024
# 2  How often does a film come along that you can ...  Jun 20, 2024
# 3  Thelma is about the indomitable human urge to ...  Jun 20, 2024
# 4  Thelma is a totally pure delight that gives Ju...  Jan 19, 2024

# %% [markdown]
# #### Create 'Title' and 'Year' fields from that of 'Film'

# %%
mcr_df[['Title', 'Year']] = mcr_df['Film'].str.extract(r'(^.*) \(([0-9]{4})\)$')

# %%
mcr_df.head()
# Out:
#             Film      Publication  Score          Critic  \
# 0  Thelma (2024)     Boston Globe    100  Odie Henderson
# 1  Thelma (2024)     Original-Cin    100       Liz Braun
# 2  Thelma (2024)    The A.V. Club    100     Cindy White
# 3  Thelma (2024)  Washington Post    100         Ty Burr
# 4  Thelma (2024)          TheWrap     90   Kristen Lopez
#
#                                              Snippet  Date Written   Title  \
# 0  This is one of the year’s best films, and the ...  Jun 18, 2024  Thelma
# 1  Thelma is really entertaining. The cast (which...  Jun 18, 2024  Thelma
# 2  How often does a film come along that you can ...  Jun 20, 2024  Thelma
# 3  Thelma is about the indomitable human urge to ...  Jun 20, 2024  Thelma
# 4  Thelma is a totally pure delight that gives Ju...  Jan 19, 2024  Thelma
#
#    Year
# 0  2024
# 1  2024
# 2  2024
# 3  2024
# 4  2024

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(mcr_df['Publication'].value_counts())
# Out:
# Publication
# Washington Post                   167
# Variety                           161
# The New York Times                159
# Los Angeles Times                 158
# Austin Chronicle                  139
# Empire                            128
# Chicago Sun-Times                 124
# San Francisco Chronicle           123
# The A.V. Club                     123
# The Globe and Mail (Toronto)      122
# The Guardian                      121
# Chicago Tribune                   118
# The Hollywood Reporter            114
# Rolling Stone                     113
# Entertainment Weekly              111
# RogerEbert.com                    107
# Boston Globe                      103
# IndieWire                         101
# Slant Magazine                     98
# ReelViews                          96
# Paste Magazine                     91
# New York Magazine (Vulture)        91
# The Playlist                       89
# Screen Daily                       87
# Time Out                           84
# The Film Stage                     84
# Film Threat                        82
# USA Today                          81
# The Telegraph                      81
# TheWrap                            79
# The New Yorker                     76
# Movie Nation                       74
# Time                               73
# Wall Street Journal                73
# Original-Cin                       71
# Total Film                         68
# The Associated Press               67
# Arizona Republic                   67
# LarsenOnFilm                       67
# Slashfilm                          65
# New York Post                      65
# The Irish Times                    64
# Screen Rant                        63
# IGN                                61
# Little White Lies                  60
# Collider                           60
# The Observer (UK)                  60
# Consequence                        60
# TV Guide Magazine                  56
# Observer                           52
# The Seattle Times                  51
# Slate                              50
# Chicago Reader                     49
# Vanity Fair                        48
# The Atlantic                       47
# CineVue                            45
# Christian Science Monitor          45
# ABC News                           45
# Village Voice                      44
# New York Daily News                43
# Miami Herald                       41
# The Daily Beast                    41
# The Independent                    41
# Polygon                            38
# Philadelphia Inquirer              38
# Salon                              33
# We Got This Covered                32
# Portland Oregonian                 31
# Vox                                30
# NME                                26
# Seattle Post-Intelligencer         25
# Uproxx                             24
# St. Louis Post-Dispatch            23
# Baltimore Sun                      23
# Charlotte Observer                 23
# L.A. Weekly                        22
# ScreenCrush                        22
# CNN                                19
# Tampa Bay Times                    18
# Newsweek                           18
# BBC                                18
# New Orleans Times-Picayune         16
# Dallas Observer                    15
# Film.com                           14
# The Film Verdict                   14
# Time Out London                    13
# San Francisco Examiner             12
# Orlando Sentinel                   10
# Premiere                           10
# Philadelphia Daily News            10
# NPR                                10
# The New Republic                    8
# Mr. Showbiz                         8
# New Times (L.A.)                    7
# The Verge                           7
# TNT RoughCut                        4
# Boxoffice Magazine                  4
# Film Journal International          3
# CNET                                3
# Movieline                           3
# Looper                              2
# McClatchy-Tribune News Service      2
# MTV News                            2
# Hitfix                              2
# i                                   1
# The Dissolve                        1
# Name: count, dtype: int64

# %% [markdown]
# ## Import my ratings

# %%
# query = "SELECT Movie_ID, Title, Year, Rating FROM allwatched"
# aw_df = pd.read_sql_query(query, engine, index_col='Movie_ID')

query = "SELECT Title, Year, Rating FROM allwatched"
aw_df = pd.read_sql_query(query, engine)


aw_df.head()
# Out:
#                        Title  Year   Rating
# 0       Only the River Flows  2023    GREAT
# 1  Pokemon Detective Pikachu  2019     None
# 2                   Good One  2024  AWESOME
# 3                  Sing Sing  2023    GREAT
# 4         The Nature of Love  2023    GREAT

# %% [markdown]
# #### Remap categorical 'Rating' field to numeric scores

# %%
my_rating_to_score = {
    None : 0,
    'GREAT': 0.625,
    'PRETTY AWESOME': 0.875,
    'AWESOME': 1,
}

aw_df['Rating'].map(my_rating_to_score)
# Out:
# 0      0.625
# 1      0.000
# 2      1.000
# 3      0.625
# 4      0.625
#        ...
# 175    0.000
# 176    0.000
# 177    0.875
# 178    1.000
# 179    0.000
# Name: Rating, Length: 180, dtype: float64

# %%
aw_df['Score'] = aw_df['Rating'].map(my_rating_to_score)
aw_df.head()
# Out:
#                        Title  Year   Rating  Score
# 0       Only the River Flows  2023    GREAT  0.625
# 1  Pokemon Detective Pikachu  2019     None  0.000
# 2                   Good One  2024  AWESOME  1.000
# 3                  Sing Sing  2023    GREAT  0.625
# 4         The Nature of Love  2023    GREAT  0.625

# %% [markdown]
# #### Create 'Publication' field to match that of the Metacritic ratings
#
# I'm setting my name as its value for all entries in this table.

# %%
aw_df['Publication'] = 'Max Ruther'
aw_score_df = aw_df[['Title','Year','Publication','Score']]
aw_score_df.head()
# Out:
#                        Title  Year Publication  Score
# 0       Only the River Flows  2023  Max Ruther  0.625
# 1  Pokemon Detective Pikachu  2019  Max Ruther  0.000
# 2                   Good One  2024  Max Ruther  1.000
# 3                  Sing Sing  2023  Max Ruther  0.625
# 4         The Nature of Love  2023  Max Ruther  0.625

# %% [markdown]
# #### In the Metacritic CR table, divide 'Score' attribute by 100
#
# This will better match my scores, as well as better resemble the grades that they are, essentially.

# %%
mcr_score_df = mcr_df[['Title','Year','Publication','Score']]
mcr_score_df.head()
# Out:
#     Title  Year      Publication  Score
# 0  Thelma  2024     Boston Globe    100
# 1  Thelma  2024     Original-Cin    100
# 2  Thelma  2024    The A.V. Club    100
# 3  Thelma  2024  Washington Post    100
# 4  Thelma  2024          TheWrap     90

# %%
mcr_score_df.loc[:, 'Score'] = mcr_df.loc[:, 'Score'].astype(float)
mcr_score_df.loc[:, 'Score'] = mcr_score_df.loc[:, 'Score'].div(100)

mcr_score_df.head()
# Out:
# C:\Users\maxru\AppData\Local\Temp\ipykernel_32664\4129479613.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1.   1.   1.   ... 0.58 0.5  0.4 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   mcr_score_df.loc[:, 'Score'] = mcr_score_df.loc[:, 'Score'].div(100)
#     Title  Year      Publication  Score
# 0  Thelma  2024     Boston Globe    1.0
# 1  Thelma  2024     Original-Cin    1.0
# 2  Thelma  2024    The A.V. Club    1.0
# 3  Thelma  2024  Washington Post    1.0
# 4  Thelma  2024          TheWrap    0.9

# %% [markdown]
# ### Combine my ratings with the publications', then pivot wider

# %%
acr_df = pd.concat([aw_score_df, mcr_score_df], ignore_index=True).sort_values(by='Title', ascending=False)

# %%
acr_df[acr_df['Title'] == '7 Days'].pivot(index=['Title', 'Year'], columns='Publication', values='Score')
# Out:
# Publication  Austin Chronicle  Collider  Film Threat  IndieWire  \
# Title  Year
# 7 Days 2021              0.67      0.91          0.8       0.75
#
# Publication  Los Angeles Times  Max Ruther  Movie Nation  Paste Magazine  \
# Title  Year
# 7 Days 2021                0.7       0.625          0.75            0.68
#
# Publication  RogerEbert.com  Screen Rant  The A.V. Club  The Film Stage  \
# Title  Year
# 7 Days 2021            0.75          0.7           0.83            0.67
#
# Publication  The Hollywood Reporter  The New York Times  The Playlist  \
# Title  Year
# 7 Days 2021                     0.7                 0.8          0.75
#
# Publication  TheWrap  Variety
# Title  Year
# 7 Days 2021      0.6      0.7

# %% [markdown]
# #### Address duplicates of Title, Year, and Publication
# These are instances where multiple critics from the same publication reviewed the same movie.

# %%
acr_df[acr_df.duplicated(['Title', 'Year', 'Publication'], keep=False)].head(8)
# acr_df[acr_df.duplicated(['Title', 'Year', 'Publication'], keep=False)][['Title','Year','Publication']].value_counts()
# acr_df[acr_df.duplicated(['Title', 'Year', 'Publication'], keep=False)].tail(8)
# Out:
#                                 Title  Year                  Publication  \
# 3301             You Hurt My Feelings  2023                 The Guardian
# 3317             You Hurt My Feelings  2023                 The Guardian
# 3721                              TÁR  2022  New York Magazine (Vulture)
# 3692                              TÁR  2022  New York Magazine (Vulture)
# 3829  Three Thousand Years of Longing  2022            Los Angeles Times
# 3826  Three Thousand Years of Longing  2022            Los Angeles Times
# 3833  Three Thousand Years of Longing  2022                 The Guardian
# 3823  Three Thousand Years of Longing  2022                 The Guardian
#
#       Score
# 3301    0.8
# 3317    0.6
# 3721    0.8
# 3692    1.0
# 3829    0.6
# 3826    0.6
# 3833    0.6
# 3823    0.6

# %% [markdown]
# Taking the duplicates aside and averaging their scores to create one record per title, year, and publication:

# %%
avgd_dups = acr_df[acr_df.duplicated(['Title', 'Year', 'Publication'], keep=False)]\
.groupby(['Title', 'Year', 'Publication'], as_index=False)\
.mean('Score')\
.sort_values(by='Title', ascending=False)

avgd_dups.head(4)
# Out:
#                               Title  Year                  Publication  Score
# 83             You Hurt My Feelings  2023                 The Guardian    0.7
# 82                              TÁR  2022  New York Magazine (Vulture)    0.9
# 81  Three Thousand Years of Longing  2022                 The Guardian    0.6
# 80  Three Thousand Years of Longing  2022            Los Angeles Times    0.6

# %% [markdown]
# Creating a separate df of the unduplicated combinations of title, year, and publication:

# %%
undupd = acr_df.drop_duplicates(['Title', 'Year', 'Publication'], keep=False)
undupd
# Out:
#                            Title  Year                   Publication  Score
# 100                    Your Name  2016                    Max Ruther  0.625
# 3669  You Were Never Really Here  2017                  The Atlantic  0.680
# 3647  You Were Never Really Here  2017  The Globe and Mail (Toronto)  1.000
# 3651  You Were Never Really Here  2017                 The A.V. Club  0.910
# 3652  You Were Never Really Here  2017                 Rolling Stone  0.880
# ...                          ...   ...                           ...    ...
# 2526                      7 Days  2021            The New York Times  0.800
# 2525                      7 Days  2021                   Film Threat  0.800
# 2524                      7 Days  2021                 The A.V. Club  0.830
# 2523                      7 Days  2021                      Collider  0.910
# 2530                      7 Days  2021                RogerEbert.com  0.750
#
# [5883 rows x 4 columns]

# %% [markdown]
# Through the concatenation of these two fresh dataframes, create a deduplicated set of review score data:

# %%
acr_dedupd = pd.concat([avgd_dups, undupd], axis=0).sort_values(by='Title', ascending=False)
# acr_dedupd[acr_dedupd['Title']=='You Hurt My Feelings']

# %% [markdown]
# Now that these fields are deduplicated, pivot wider on their basis:

# %%
acr_df2 = acr_dedupd.pivot(index=['Title', 'Year'], columns='Publication', values='Score')
acr_df2.head()
# Out:
# Publication           ABC News  Arizona Republic  Austin Chronicle  BBC  \
# Title           Year
# 7 Days          2021       NaN               NaN              0.67  NaN
# A Knight's Tale 2001       NaN               NaN               NaN  NaN
# A Knight’s Tale 2001       NaN               NaN              0.67  NaN
# Adaptation      2002       NaN               NaN               NaN  NaN
# Adaptation.     2002       NaN               NaN              0.89  NaN
#
# Publication           Baltimore Sun  Boston Globe  Boxoffice Magazine  CNET  \
# Title           Year
# 7 Days          2021            NaN           NaN                 NaN   NaN
# A Knight's Tale 2001            NaN           NaN                 NaN   NaN
# A Knight’s Tale 2001           0.38          0.75                 NaN   NaN
# Adaptation      2002            NaN           NaN                 NaN   NaN
# Adaptation.     2002           0.75          1.00                 NaN   NaN
#
# Publication           CNN  Charlotte Observer  ...  USA Today  Uproxx  \
# Title           Year                           ...
# 7 Days          2021  NaN                 NaN  ...        NaN     NaN
# A Knight's Tale 2001  NaN                 NaN  ...        NaN     NaN
# A Knight’s Tale 2001  NaN                 NaN  ...       0.50     NaN
# Adaptation      2002  NaN                 NaN  ...        NaN     NaN
# Adaptation.     2002  NaN                 0.5  ...       0.63     NaN
#
# Publication           Vanity Fair  Variety  Village Voice  Vox  \
# Title           Year
# 7 Days          2021          NaN      0.7            NaN  NaN
# A Knight's Tale 2001          NaN      NaN            NaN  NaN
# A Knight’s Tale 2001          NaN      0.3            0.4  NaN
# Adaptation      2002          NaN      NaN            NaN  NaN
# Adaptation.     2002          NaN      0.9            0.9  NaN
#
# Publication           Wall Street Journal  Washington Post  \
# Title           Year
# 7 Days          2021                  NaN              NaN
# A Knight's Tale 2001                  NaN              NaN
# A Knight’s Tale 2001                  0.7             0.75
# Adaptation      2002                  NaN              NaN
# Adaptation.     2002                  0.8             1.00
#
# Publication           We Got This Covered   i
# Title           Year
# 7 Days          2021                  NaN NaN
# A Knight's Tale 2001                  NaN NaN
# A Knight’s Tale 2001                  NaN NaN
# Adaptation      2002                  NaN NaN
# Adaptation.     2002                  NaN NaN
#
# [5 rows x 107 columns]

# %% [markdown]
# ### Review score counts per movie

# %%
rev_counts_per_movie = acr_df2.notna().sum(axis=1).sort_values(ascending=False)
rev_counts_per_movie.head(40)
# Out:
# Title                                      Year
# No Hard Feelings                           2023    51
# The Zone of Interest                       2023    51
# Barbie                                     2023    51
# Blade Runner 2049                          2017    51
# M3GAN                                      2022    51
# The Banshees of Inisherin                  2022    51
# All of Us Strangers                        2023    51
# Moonlight                                  2016    51
# Star Trek Beyond                           2016    51
# Spider-Man: Into the Spider-Verse          2018    51
# Civil War                                  2024    51
# Challengers                                2024    51
# The Unbearable Weight of Massive Talent    2022    51
# Drive-Away Dolls                           2024    50
# Dungeons & Dragons: Honor Among Thieves    2023    50
# Three Billboards Outside Ebbing, Missouri  2017    50
# Crazy Rich Asians                          2018    50
# Furiosa: A Mad Max Saga                    2024    50
# Love Lies Bleeding                         2024    50
# The Lighthouse                             2019    50
# The Holdovers                              2023    50
# May December                               2023    50
# No Time to Die                             2021    50
# Oppenheimer                                2023    50
# Parasite                                   2019    50
# Past Lives                                 2023    50
# Saltburn                                   2023    50
# Borat Subsequent Moviefilm                 2020    50
# Shang-Chi and the Legend of the Ten Rings  2021    50
# Asteroid City                              2023    50
# American Fiction                           2023    50
# Alien: Romulus                             2024    50
# Hit Man                                    2023    49
# Licorice Pizza                             2021    49
# Poor Things                                2023    49
# TÁR                                        2022    49
# Don’t Look Up                              2021    49
# The Substance                              2024    48
# Dune                                       2021    48
# Tenet                                      2020    48
# dtype: int64

# %%
rev_counts_per_movie.plot.bar()
# Out:
# <Axes: xlabel='Title,Year'>

# %%
rev_counts_per_movie.plot.bar()
plt.show()

# %%
movie_cnt_per_rev_cnt = acr_df2.notna().sum(axis=1).value_counts().sort_index(ascending=False)
movie_cnt_per_rev_cnt
# Out:
# 51    13
# 50    19
# 49     5
# 48     6
# 47     8
# 45     4
# 44     3
# 43     3
# 42     1
# 41     5
# 39     6
# 38     8
# 37     3
# 36     2
# 35     4
# 34     4
# 33     1
# 32     3
# 31     8
# 30     2
# 29     3
# 28     4
# 26     4
# 25     5
# 24     1
# 23     4
# 21     5
# 20     5
# 19     5
# 18     4
# 17     6
# 16     3
# 15     1
# 14     3
# 13     1
# 12     4
# 11     2
# 10     2
# 9      3
# 8      1
# 6      1
# 5      2
# 3      2
# 2      1
# 1     38
# Name: count, dtype: int64

# %%
movie_cnt_per_rev_cnt.sort_index(ascending=True).plot.bar()
plt.show()

# %% [markdown]
# ### Review counts per publication

# %% [markdown]
# Most frequently reviewing publications:

# %%
rev_count_per_pub = acr_df2.notna().sum(axis=0).sort_values(ascending=False)
rev_count_per_pub.head(30)
# Out:
# Publication
# Max Ruther                      180
# Variety                         161
# The New York Times              159
# Los Angeles Times               155
# Washington Post                 141
# Austin Chronicle                139
# Empire                          127
# Chicago Sun-Times               124
# San Francisco Chronicle         122
# The Globe and Mail (Toronto)    121
# The A.V. Club                   120
# Chicago Tribune                 118
# The Hollywood Reporter          114
# Rolling Stone                   113
# Entertainment Weekly            111
# RogerEbert.com                  107
# Boston Globe                    103
# The Guardian                    103
# IndieWire                       101
# Slant Magazine                   98
# ReelViews                        96
# Paste Magazine                   91
# New York Magazine (Vulture)      90
# The Playlist                     89
# Screen Daily                     87
# Time Out                         84
# The Film Stage                   84
# USA Today                        81
# The Telegraph                    80
# Film Threat                      80
# dtype: int64

# %% [markdown]
# Least frequently reviewing publications:

# %%
rev_count_per_pub.tail(30)
# Out:
# Publication
# L.A. Weekly                       22
# CNN                               19
# BBC                               18
# Newsweek                          18
# Tampa Bay Times                   18
# New Orleans Times-Picayune        16
# Dallas Observer                   15
# The Film Verdict                  14
# Time Out London                   13
# San Francisco Examiner            12
# Philadelphia Daily News           10
# NPR                               10
# Premiere                          10
# Film.com                          10
# Orlando Sentinel                  10
# Mr. Showbiz                        8
# The New Republic                   8
# The Verge                          7
# New Times (L.A.)                   7
# Boxoffice Magazine                 4
# TNT RoughCut                       4
# Film Journal International         3
# Movieline                          3
# CNET                               3
# McClatchy-Tribune News Service     2
# Hitfix                             2
# Looper                             2
# MTV News                           2
# The Dissolve                       1
# i                                  1
# dtype: int64

# %% [markdown]
# Plotting the review counts per publication:

# %%
rev_count_per_pub.plot.bar()
# Out:
# <Axes: xlabel='Publication'>

# %% [markdown]
# ### Correlations between my ratings and the publications'

# %%
pub_corrs = acr_df2.corr()['Max Ruther'].sort_values(ascending=False).rename('Corr to Max')

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(pub_corrs)
# Out:
# Publication
# TNT RoughCut                      1.000000
# MTV News                          1.000000
# Max Ruther                        1.000000
# Film Journal International        1.000000
# McClatchy-Tribune News Service    1.000000
# The Verge                         0.924850
# Boxoffice Magazine                0.774597
# NPR                               0.712012
# Philadelphia Daily News           0.694425
# Baltimore Sun                     0.629395
# Philadelphia Inquirer             0.605363
# Salon                             0.592860
# Film.com                          0.591982
# Orlando Sentinel                  0.541314
# The Globe and Mail (Toronto)      0.540472
# USA Today                         0.539914
# Entertainment Weekly              0.538435
# Tampa Bay Times                   0.535961
# Miami Herald                      0.509227
# Movieline                         0.500000
# L.A. Weekly                       0.498425
# Polygon                           0.493636
# Village Voice                     0.492665
# We Got This Covered               0.486535
# Premiere                          0.485048
# The New York Times                0.475813
# Chicago Tribune                   0.474759
# Dallas Observer                   0.471189
# Washington Post                   0.470176
# Seattle Post-Intelligencer        0.467430
# CNN                               0.465729
# The Seattle Times                 0.462767
# Empire                            0.460232
# St. Louis Post-Dispatch           0.458096
# Chicago Reader                    0.457941
# San Francisco Chronicle           0.454771
# Chicago Sun-Times                 0.454129
# Portland Oregonian                0.453887
# Time Out London                   0.452089
# Christian Science Monitor         0.443128
# IGN                               0.441371
# Austin Chronicle                  0.423418
# Los Angeles Times                 0.421683
# ScreenCrush                       0.418003
# Newsweek                          0.414416
# Uproxx                            0.411736
# Film Threat                       0.387995
# New York Daily News               0.385197
# CineVue                           0.379821
# Charlotte Observer                0.377755
# Total Film                        0.374423
# San Francisco Examiner            0.372209
# The A.V. Club                     0.366396
# Rolling Stone                     0.365248
# IndieWire                         0.365007
# Time Out                          0.361274
# Boston Globe                      0.358562
# TV Guide Magazine                 0.347956
# Variety                           0.347935
# The New Yorker                    0.337567
# New York Magazine (Vulture)       0.335801
# ReelViews                         0.323255
# New York Post                     0.320311
# Wall Street Journal               0.318095
# Arizona Republic                  0.306168
# Movie Nation                      0.304119
# Observer                          0.303624
# The Associated Press              0.294241
# The Observer (UK)                 0.291883
# LarsenOnFilm                      0.288412
# RogerEbert.com                    0.283116
# The Hollywood Reporter            0.277086
# BBC                               0.267092
# New Orleans Times-Picayune        0.259303
# Consequence                       0.244783
# Screen Rant                       0.244702
# The Telegraph                     0.241823
# The Film Stage                    0.232111
# Original-Cin                      0.225232
# NME                               0.215188
# Time                              0.213329
# The Guardian                      0.213323
# Screen Daily                      0.208272
# Vox                               0.201524
# Slant Magazine                    0.197688
# Vanity Fair                       0.189085
# The Atlantic                      0.188823
# Paste Magazine                    0.186753
# Slashfilm                         0.185755
# The Playlist                      0.132677
# The Independent                   0.107871
# The Daily Beast                   0.105568
# ABC News                          0.061220
# Little White Lies                 0.059883
# Slate                             0.043236
# Collider                          0.016446
# The Irish Times                   0.000805
# The New Republic                 -0.005404
# TheWrap                          -0.037689
# Mr. Showbiz                      -0.071224
# The Film Verdict                 -0.152418
# CNET                                   NaN
# Hitfix                                 NaN
# Looper                                 NaN
# New Times (L.A.)                       NaN
# The Dissolve                           NaN
# i                                      NaN
# Name: Corr to Max, dtype: float64

# %%
pub_corr_n_cnts = pd.merge(pub_corrs, rev_count_per_pub.rename('Review Count'), on='Publication')

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(pub_corr_n_cnts[pub_corr_n_cnts['Review Count']>80])
# Out:
#                               Corr to Max  Review Count
# Publication
# Max Ruther                       1.000000           180
# The Globe and Mail (Toronto)     0.540472           121
# USA Today                        0.539914            81
# Entertainment Weekly             0.538435           111
# The New York Times               0.475813           159
# Chicago Tribune                  0.474759           118
# Washington Post                  0.470176           141
# Empire                           0.460232           127
# San Francisco Chronicle          0.454771           122
# Chicago Sun-Times                0.454129           124
# Austin Chronicle                 0.423418           139
# Los Angeles Times                0.421683           155
# The A.V. Club                    0.366396           120
# Rolling Stone                    0.365248           113
# IndieWire                        0.365007           101
# Time Out                         0.361274            84
# Boston Globe                     0.358562           103
# Variety                          0.347935           161
# New York Magazine (Vulture)      0.335801            90
# ReelViews                        0.323255            96
# RogerEbert.com                   0.283116           107
# The Hollywood Reporter           0.277086           114
# The Film Stage                   0.232111            84
# The Guardian                     0.213323           103
# Screen Daily                     0.208272            87
# Slant Magazine                   0.197688            98
# Paste Magazine                   0.186753            91
# The Playlist                     0.132677            89

# %% [markdown]
# ### Films that lack representation in the Metacritic CR data

# %%
films_lacking_mcr_scrape = list(rev_counts_per_movie[rev_counts_per_movie==1].index)
films_lacking_mcr_scrape
# Out:
# [('Three Billboards', '2017'),
#  ('Dragonheart', '1996'),
#  ('Drive My Car', '2021'),
#  ('Ex Machina', '2014'),
#  ('Titane', '2021'),
#  ('Nate - A One Man Show', '2020'),
#  ('The Worst Person in the World', '2021'),
#  ('Confess, Fletch', '2022'),
#  ('Black Dynamite', '2009'),
#  ('TÃ¡r', '2022'),
#  ('Under the Skin', '2013'),
#  ('Barbarian', '2022'),
#  ('Raw', '2016'),
#  ('Akira', '1988'),
#  ('Air Bud', '1997'),
#  ('Adaptation', '2002'),
#  ('Pokemon: The First Movie', '1998'),
#  ('Pokemon 2000', '2000'),
#  ('Gone in 60 Seconds', '2000'),
#  ('Goodfellas', '1990'),
#  ('Sweetie', '1989'),
#  ('Nomadland', '2020'),
#  ('Millennium Actress', '2001'),
#  ('Memories', '1995'),
#  ('Terms of Endearment', '1983'),
#  ('Mad Max: Fury Road', '2015'),
#  ('The Card Counter', '2021'),
#  ('Spanglish', '2004'),
#  ('Palm Springs', '2020'),
#  ('Rye Lane', '2023'),
#  ('In the Cut', '2003'),
#  ('Sorry To Bother You', '2018'),
#  ('The Next Karate Kid', '1994'),
#  ('The Power of the Dog', '2021'),
#  ("A Knight's Tale", '2001'),
#  ('Pokemon Detective Pikachu', '2019'),
#  ("The Teachers' Lounge", '2023'),
#  ('Your Name', '2016')]
