# %% [markdown]
# # MovieList Analysis
# ### Max Ruther

# %% [markdown]
# ## Setup
#
# ##### Imports

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt

# %% [markdown]
# ##### Seed for Randomization

# %%
rand_st = 44

# %% [markdown]
# ##### Connect the SQLAlchemy engine to my local MySQL movie database

# %%
engine = create_engine('mysql://root:yos@localhost/moviedb')
conn = engine.connect()

# %% [markdown]
# ## Load and Merge Tables

# %% [markdown]
# ##### Load in _critic_ratings_ table

# %%
query = "SELECT * FROM critic_ratings"

cr_df = pd.read_sql_query(query, engine, index_col='Movie_ID')
cr_df.head(5)
# Out:
#                         Title  Year  IMDB_Score  RT_Score  MetaC_Score  \
# Movie_ID
# 1                    Good One  2024        0.71      0.97          NaN
# 2                   Sing Sing  2023        0.82      0.97         0.85
# 3           Y Tu Mama Tambien  2001        0.77      0.90         0.89
# 4            Gasoline Rainbow  2023        0.63      0.93         0.80
# 5         Evil Does Not Exist  2023        0.70      0.91         0.83
#
#           Ebert_Score
# Movie_ID
# 1                 NaN
# 2                 4.0
# 3                 4.0
# 4                 4.0
# 5                 3.5

# %% [markdown]
# ##### Load in _allwatched_ table

# %%
query = "SELECT * FROM allwatched"

aw_df = pd.read_sql_query(query, engine, index_col='Movie_ID')
aw_df.loc[12:16]
# Out:
#                             Title  Year Release_Date    Director  Watched  \
# Movie_ID
# 12             The Nature of Love  2023   2024-07-05      Chokri        1
# 13                         Oddity  2024   2024-07-19    McCarthy        1
# 14                    Challengers  2024   2024-04-26  Guadagnino        1
# 15        Furiosa: A Mad Max Saga  2024   2024-05-24      Miller        1
# 16                 Polite Society  2023   2023-01-21     Manzoor        1
#
#           Watched_in_theater   Rating Date_watched  native_ordering
# Movie_ID
# 12                         1    GREAT   2024-08-04               12
# 13                         1    GREAT   2024-07-28               13
# 14                         1    GREAT   2024-06-22               14
# 15                         1  AWESOME   2024-06-13               15
# 16                         0    GREAT   2024-06-07               11

# %% [markdown]
# ### Merging Tables

# %%
df = aw_df.merge(cr_df, how='inner', on=['Movie_ID', 'Title', 'Year'])
# df = aw_df.merge(cr_df, how='inner', on=['Title', 'Year'])
df.head(5)
# Out:
#                             Title  Year Release_Date    Director  Watched  \
# Movie_ID
# 12             The Nature of Love  2023   2024-07-05      Chokri        1
# 13                         Oddity  2024   2024-07-19    McCarthy        1
# 14                    Challengers  2024   2024-04-26  Guadagnino        1
# 15        Furiosa: A Mad Max Saga  2024   2024-05-24      Miller        1
# 16                 Polite Society  2023   2023-01-21     Manzoor        1
#
#           Watched_in_theater   Rating Date_watched  native_ordering  \
# Movie_ID
# 12                         1    GREAT   2024-08-04               12
# 13                         1    GREAT   2024-07-28               13
# 14                         1    GREAT   2024-06-22               14
# 15                         1  AWESOME   2024-06-13               15
# 16                         0    GREAT   2024-06-07               11
#
#           IMDB_Score  RT_Score  MetaC_Score  Ebert_Score
# Movie_ID
# ...

# %% [markdown]
# ### Select features and encode target

# %% [markdown]
# #### Select features
#
# The features listed in the following code cell strike me as potentially useful for predicting my _Rating_ of a movie.

# %%
df[['Title','Year','Release_Date', 'Watched_in_theater', 'Date_watched', 'Rating', 'Ebert_Score', 'MetaC_Score', 'IMDB_Score', 'RT_Score']]
# Out:
#                             Title  Year Release_Date  Watched_in_theater  \
# Movie_ID
# 12             The Nature of Love  2023   2024-07-05                   1
# 13                         Oddity  2024   2024-07-19                   1
# 14                    Challengers  2024   2024-04-26                   1
# 15        Furiosa: A Mad Max Saga  2024   2024-05-24                   1
# 16                 Polite Society  2023   2023-01-21                   0
# ...                           ...   ...          ...                 ...
# 219                 Reign of Fire  2002   2002-07-12                   0
# 220                       Rampant  2018   2018-11-02                   0
# 221           Sorry To Bother You  2018   2018-01-20                   0
# 242              Three Billboards  2017   2017-11-10                   0
# 243                          Lamb  2021   2021-10-26                   0
#
#          Date_watched          Rating  Ebert_Score  MetaC_Score  IMDB_Score  \
# ...

# %% [markdown]
# ##### For this analysis, selecting even fewer features.
# On second thought: for simplicity, I will this time only select rating attributes and _Watched_in_theater_. I intend to leverage these fields I've discarded later on.

# %%
df1 = df[['Watched_in_theater', 'Ebert_Score', 'MetaC_Score', 'IMDB_Score', 'RT_Score', 'Rating']]
df1.head(5)
# Out:
#           Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score  RT_Score  \
# Movie_ID
# 12                         1          4.0          NaN        0.70      0.92
# 13                         1          3.5         0.78        0.68      0.96
# 14                         1          3.5         0.82        0.72      0.88
# 15                         1          4.0         0.79        0.76      0.90
# 16                         0          3.5         0.75        0.66      0.91
#
#            Rating
# Movie_ID
# 12          GREAT
# 13          GREAT
# 14          GREAT
# 15        AWESOME
# 16          GREAT

# %% [markdown]
# #### Encode target field: _Rating_ -> _anyAwesome_
#
# If my rating is 'PRETTY AWESOME' or 'AWESOME', then _anyAwesome_ will show a '1'.

# %%
df1.loc[:, ('anyAwesome')] = np.where(df1.loc[:, ('Rating')].str.contains('AWESOME'), 1, 0)
df1.head(10)
# Out:
# C:\Users\maxru\AppData\Local\Temp\ipykernel_60092\4153498358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:, ('anyAwesome')] = np.where(df1.loc[:, ('Rating')].str.contains('AWESOME'), 1, 0)
#           Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score  RT_Score  \
# Movie_ID
# 12                         1          4.0          NaN        0.70      0.92
# 13                         1          3.5         0.78        0.68      0.96
# 14                         1          3.5         0.82        0.72      0.88
# 15                         1          4.0         0.79        0.76      0.90
# 16                         0          3.5         0.75        0.66      0.91
# ...

# %%
df1.to_csv('../data/watch_df_1.csv', index=True)

# %% [markdown]
# ##### Dropping the _Rating_ field, following its encoding.

# %%
df1 = df1.loc[:, df1.columns != 'Rating']

# %%
df1.describe()
# Out:
#        Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score    RT_Score  \
# count          176.000000   162.000000   169.000000  176.000000  175.000000
# mean             0.147727     3.166667     0.702367    0.699091    0.792571
# std              0.355842     0.755929     0.166970    0.080316    0.213592
# min              0.000000     1.000000     0.240000    0.300000    0.050000
# 25%              0.000000     2.500000     0.590000    0.650000    0.715000
# 50%              0.000000     3.500000     0.740000    0.700000    0.880000
# 75%              0.000000     4.000000     0.820000    0.750000    0.940000
# max              1.000000     4.000000     1.000000    0.870000    1.000000
#
#        anyAwesome
# count  176.000000
# mean     0.278409
# std      0.449495
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ### Missing Values

# %% [markdown]
# #### Identifying Missing Values

# %% [markdown]
# Total number of rows in df:

# %%
df1.shape[0]
# Out:
# 176

# %% [markdown]
# Total number of rows in df after dropping rows with missing values:

# %%
df1.dropna().shape[0]
# Out:
# 160

# %% [markdown]
# Number of rows with missing values:

# %%
df1.shape[0] - df1.dropna().shape[0]
# Out:
# 16

# %% [markdown]
# Count of missing values by column:

# %%
df1.isna().sum(axis=0)
# Out:
# Watched_in_theater     0
# Ebert_Score           14
# MetaC_Score            7
# IMDB_Score             0
# RT_Score               1
# anyAwesome             0
# dtype: int64

# %% [markdown]
# Viewing all rows that contain a missing value:

# %%
# df1.isna().any(axis=1).sum()
df1[df1.isna().any(axis=1)]
# Out:
#           Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score  RT_Score  \
# Movie_ID
# 12                         1          4.0          NaN        0.70      0.92
# 56                         0          NaN         0.36        0.45      0.07
# 57                         0          NaN         0.42        0.61      0.45
# 59                         0          3.0          NaN        0.53      0.48
# 115                        0          NaN          NaN        0.66      1.00
# 120                        0          NaN          NaN        0.67      0.88
# 162                        0          NaN         0.28        0.75      0.19
# 163                        0          NaN         0.70        0.73      0.77
# 165                        0          NaN         0.70        0.78      0.93
# 166                        0          NaN         0.67        0.80      0.91
# 172                        1          NaN          NaN        0.30      0.05
# ...

# %% [markdown]
# #### Dropping Missing Values

# %%
df1 = df1.dropna()

# %% [markdown]
# ### Save df to file before splitting

# %%
df1.head()
# Out:
#           Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score  RT_Score  \
# Movie_ID
# 13                         1          3.5         0.78        0.68      0.96
# 14                         1          3.5         0.82        0.72      0.88
# 15                         1          4.0         0.79        0.76      0.90
# 16                         0          3.5         0.75        0.66      0.91
# 17                         0          4.0         0.74        0.70      0.85
#
#           anyAwesome
# Movie_ID
# 13                 0
# 14                 0
# 15                 1
# 16                 0
# 17                 0

# %%
# df1.to_csv('../data/watch_df_2.csv', index=True)
df1.to_csv('../data/mList_df_all.csv', index=True)

# %% [markdown]
# ### Split data for model training

# %% [markdown]
# #### Create the predictor set

# %%
X1 = df1.loc[:, df1.columns != 'anyAwesome']
X1.head()
# Out:
#           Watched_in_theater  Ebert_Score  MetaC_Score  IMDB_Score  RT_Score
# Movie_ID
# 13                         1          3.5         0.78        0.68      0.96
# 14                         1          3.5         0.82        0.72      0.88
# 15                         1          4.0         0.79        0.76      0.90
# 16                         0          3.5         0.75        0.66      0.91
# 17                         0          4.0         0.74        0.70      0.85

# %% [markdown]
# #### Create the target set

# %%
y1 = df1.loc[:, ('anyAwesome')]
y1.head()
# Out:
# Movie_ID
# 13    0
# 14    0
# 15    1
# 16    0
# 17    0
# Name: anyAwesome, dtype: int32

# %% [markdown]
# #### Split these into train and test sets

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2,
                                                    random_state=rand_st)

# %% [markdown]
# #### Save these split-up sets to files

# %%
X1_train.to_csv('../data/mList_df_X_train.csv', index=True)
X1_test.to_csv('../data/mList_df_X1_test.csv', index=True)
y1_train.to_csv('../data/mList_df_y1_train.csv', index=True)
y1_test.to_csv('../data/mList_df_y1_test.csv', index=True)

# %% [markdown]
# ## Modelling - Decision Tree

# %%
DT_1 = DecisionTreeClassifier(criterion='gini', max_depth=3,
                             min_samples_split=2, random_state=rand_st)

DT_1.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=44)

# %%
test_preds = DT_1.predict(X1_test)

# %%
print(classification_report(test_preds, y1_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87        29
#            1       0.25      0.67      0.36         3
#
#     accuracy                           0.78        32
#    macro avg       0.60      0.73      0.62        32
# weighted avg       0.89      0.78      0.82        32

# %%
X1.columns
# Out:
# Index(['Watched_in_theater', 'Ebert_Score', 'MetaC_Score', 'IMDB_Score',
#        'RT_Score'],
#       dtype='object')

# %%
plt.figure(figsize=(16,12))
plot_tree(DT_1, feature_names=X1.columns, class_names=['Bad', 'Good'], fontsize=10)
plt.show()

# %% [markdown]
# ### Looking further into leaf node #4
#
# This leaf node is by far the most impure, showing a gini score of 0.476. Perhaps drilling down on the films that fall into this node might shed light on how to best improve the model. Is there a pattern that might separate the fairly awesome films from the awe-less?

# %%
df['Rating'] = pd.Categorical(df['Rating'],
                              categories=['GREAT', 'PRETTY AWESOME', 'AWESOME'],
                              ordered=True)

# %%
df[(df['MetaC_Score'] <= 0.855) & (df['Ebert_Score'] > 3.25) & (df['RT_Score'] > 0.785)].sort_values('Rating', ascending=False)
# Out:
#                                             Title  Year Release_Date  \
# Movie_ID
# 75                                     Earth Mama  2023   2023-07-07
# 15                        Furiosa: A Mad Max Saga  2024   2024-05-24
# 24                                      Civil War  2024   2024-04-12
# 117                             Dinner in America  2020   2020-01-24
# 109                                 The Holdovers  2023   2023-08-31
# 66                           The Teachers' Lounge  2023   2023-12-25
# 69                                   May December  2023   2023-05-20
# 89                                            Raw  2016   2017-03-10
# 169                                    Ex Machina  2014   2015-04-24
# 86                                 Sound of Metal  2019   2020-11-20
# 119                    Borat Subsequent Moviefilm  2020   2020-10-23
# 111                                    Shiva Baby  2020   2021-04-02
# ...

# %% [markdown]
# ### Takeaway: Add Genre data
#
# When I look through this table, a differentiating pattern isn't as glaring as I might've hoped. However, I wonder whether films associated with either the comedy or romance genres might tend to be rated poorer.
#
# Being a fan of comedy, I would be surprised if such a pattern proved determinant. But regardless, adding genre fields to this data appears advantageous.

# %%
# df[df['Date_watched'].astype(str).str.contains('2022')].sort_values(by='Date_watched')
